# %% [markdown]
# # 04. Model Evaluation
#
# This notebook focuses on:
# - Exhaustive evaluation on the Test set.
# - Calculation of key metrics: Accuracy, F1-Score, ROC-AUC.
# - Analysis of feature importance.

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import joblib

# %% [markdown]
# ## 1. Load Data and Artifacts

# %%
# X_test, y_test = load_test_data(...)
# model_pipeline = joblib.load('artifacts/full_pipeline.pkl')

# %% [markdown]
# ## 2. Evaluation Metrics Calculation

# %%
def evaluate_performance(model_pipeline, X_test, y_test):
    """
    Calculates and reports detailed classification metrics including ROC-AUC.
    """
    # y_pred = model_pipeline.predict(X_test)
    # y_proba = model_pipeline.predict_proba(X_test)[:, 1]
    
    # print(classification_report(y_test, y_pred))
    # print('ROC-AUC:', roc_auc_score(y_test, y_proba))
    pass

# %% [markdown]
# ## 3. Confusion Matrix & Feature Importance

# %%
def plot_confusion_matrix_custom(y_test, y_pred):
    """Generates a confusion matrix display to evaluate misclassifications."""
    pass

def extract_feature_importances(model_pipeline, feature_names):
    """Extracts and plots feature importances from the estimator inside the pipeline."""
    pass
