# %% [markdown]
# # 03. Supervised Model Training
#
# This notebook executes the training phase:
# - Generates Train/Test Splits securely.
# - Combines the Feature Engineering pipeline with an Estimator (LightGBM/XGBoost) into a single overarching Pipeline.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedKFold
import lightgbm as lgb
from sklearn.pipeline import Pipeline
import joblib

# %% [markdown]
# ## 1. Train/Test Split

# %%
def create_data_splits(df, target_col, test_size=0.2, random_state=42):
    """Safely partitions the labeled dataframe into train and test sets using stratification."""
    # X = df.drop(columns=[target_col])
    # y = df[target_col]
    # return train_test_split(X, y, test_size=test_size, stratify=y, random_state=random_state)
    pass

# %% [markdown]
# ## 2. Complete Pipeline Assembly

# %%
def build_full_model_pipeline(preprocessor, params=None):
    """
    Assembles preprocessing and modeling into a single sklearn Pipeline.
    Optimized for massive datasets by supporting LightGBM.
    """
    if params is None:
        params = {'n_estimators': 100, 'random_state': 42}
        
    estimator = lgb.LGBMClassifier(**params)
    
    full_pipeline = Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('classifier', estimator)
    ])
    
    return full_pipeline

# %% [markdown]
# ## 3. Training and Serialization

# %%
def train_model(pipeline, X_train, y_train):
    """Fits the complete pipeline exclusively to the training data."""
    # pipeline.fit(X_train, y_train)
    # return pipeline
    pass
