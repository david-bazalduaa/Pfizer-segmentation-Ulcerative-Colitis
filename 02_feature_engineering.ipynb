# %% [markdown]
# # 02. Feature Engineering & Preprocessing Pipelines
#
# This phase prepares the data for modeling:
# - Strict setup of `sklearn.pipeline.Pipeline` to prevent data leakage.
# - Imputation, encoding (efficient for high cardinality), and scaling.

# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
import joblib

# %% [markdown]
# ## 1. Feature Definition

# %%
# NUMERIC_FEATURES = ['age', 'score']
# CATEGORICAL_FEATURES = ['category_a', 'category_b']

# %% [markdown]
# ## 2. Pipeline Configuration

# %%
def build_preprocessing_pipeline(numeric_cols, categorical_cols):
    """
    Builds a robust scikit-learn pipeline for data transformation.
    This structure inherently prevents target leakage when applied inside cross-validation.
    """
    numeric_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler', StandardScaler())
    ])
    
    categorical_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
        ('encoder', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
    ])
    
    preprocessor = ColumnTransformer(transformers=[
        ('num', numeric_transformer, numeric_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])
    
    return preprocessor

# %% [markdown]
# ## 3. Fitting and Saving the Pipeline

# %%
def save_pipeline(pipeline, file_path):
    """Persists the pipeline configuration to disk for reproducibility and inference."""
    # joblib.dump(pipeline, file_path)
    pass
